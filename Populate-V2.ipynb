# %%
import pandas as pd
df=pd.read_json("gares.json")
df.head()
len(df)
# Out:
# 159

# %%
dfmu=pd.read_json("musee.json")
print(len(dfmu))
dfmu.head()
# Out:
# 1221
#   Identifiant Muséofile Région administrative Département          Commune  \
# 0                 M0967  Auvergne-Rhône-Alpes         Ain          Lochieu
# 1                 M0964  Auvergne-Rhône-Alpes         Ain  Bourg-en-Bresse
# 2                 M0965  Auvergne-Rhône-Alpes         Ain           Briord
# 3                 M0971  Auvergne-Rhône-Alpes         Ain     Pont-de-Vaux
# 4                 M0974  Auvergne-Rhône-Alpes         Ain          Seyssel
#
#                              Nom officiel du musée  \
# 0                          musée du Bugey-Valromey
# 1                         musées des pays de l'Ain
# 2  musée de la société d'histoire et d'archéologie
# 3                                 musée Chintreuil
# 4                                    musée du bois
#
#                                  Adresse  Code Postal  \
# 0                         3 rue Centrale       1260.0
# 1            34, rue Général Delestraint       1000.0
# 2                                   None       1470.0
# 3  66 rue Maréchal de Lattre-de-Tassigny       1190.0
# 4                 place de la République       1420.0
#
#                  Téléphone                                                URL  \
# 0           04 79 87 52 23  patrimoines.ain.fr/n/musee-du-bugey-valromey/n...
# 1           04 74 32 10 60  www.ain.fr/solutions-services-infos-pratiques/...
# 2  04 74 36 72 06 (mairie)  patrimoines.ain.fr/n/musee-d-archeologie-de-br...
# 3           03 85 51 45 75                          www.musee-chintreuil.com/
# 4  04 50 56 21 55 (mairie)                                               None
#
#     Latitude  Longitude REF_Deps
# 0  45.930633   5.727664  0121801
# 1  46.196543   5.219217  0105302
# 2  45.781653   5.458569  0106401
# 3  46.430076   4.938125  0130501
# 4  45.959038   5.831489  0140701

# %%
dfmu = dfmu[dfmu['Code Postal'].notna()]
dfmu=dfmu.reset_index()
len(dfmu)
# Out:
# 1220

# %%
len(df)+len(dfmu)
# Out:
# 1379

# %%
from rdflib import Graph, Literal, RDF, URIRef
# rdflib knows about quite a few popular namespaces, like W3C ontologies, schema.org etc.
from rdflib.namespace import FOAF , XSD, RDFS

# Create a Graph
g = Graph()


baseURI="http://exemple.org"
place=URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#Place")
gare=URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#TrainStation")

for i in range(len(df)):
    start=URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#"+str(i))


    
# Add triples using store's add() method.
    g.add((start, RDF.type, gare))
    g.add((gare, RDFS.subClassOf, place))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#department"), Literal(df.loc[i,"NOM_DEP"],datatype=XSD.string)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#latitude"), Literal(df.loc[i,"Latitude"],datatype=XSD.float)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#longitude"), Literal(df.loc[i,"Longitude"],datatype=XSD.float)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#City"), Literal(df.loc[i,"code_postal"],datatype=XSD.integer)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#name"), Literal(df.loc[i,"Nom_Gare"],datatype=XSD.string)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#numberOfUsers"), Literal(df.loc[i,"traffic"],datatype=XSD.string)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#region"), Literal(df.loc[i,"INSEE_REG"],datatype=XSD.integer)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#wifi"), Literal(df.loc[i,"service_wifi"],datatype=XSD.string)))

museum=URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#Museum")
for i in range(len(df),len(dfmu)+len(df)):
    start=URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#"+str(i))
    j=i-len(df)
    g.add((start, RDF.type, museum))
    g.add((museum, RDFS.subClassOf, place))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#department"), Literal(dfmu.loc[j,"Département"],datatype=XSD.string)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#latitude"), Literal(dfmu.loc[j,"Latitude"],datatype=XSD.float)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#longitude"), Literal(dfmu.loc[j,"Longitude"],datatype=XSD.float)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#City"), Literal(dfmu.loc[j,"Code Postal"],datatype=XSD.integer)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#name"), Literal(dfmu.loc[j,"Nom officiel du musée"],datatype=XSD.string)))
    g.add((start, URIRef("http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#Localisation"), Literal(dfmu.loc[j,"Adresse"],datatype=XSD.string)))
    

# print all the data in the Notation3 format
print("--- printing mboxes ---")
print(g.serialize(format='ttl'))
g.serialize(destination='triple.ttl', format='turtle',base=baseURI)
# Out:
# --- printing mboxes ---
# @prefix ns1: <http://www.semanticweb.org/sébastien/ontologies/2022/2/untitled-ontology-22#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ns1:0 a ns1:TrainStation ;
#     ns1:City 13592 ;
#     ns1:department "Ain"^^xsd:string ;
#     ns1:latitude "46.097"^^xsd:float ;
#     ns1:longitude "4.8469999999999995"^^xsd:float ;
#     ns1:name "Aix-en-Provence TGV"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 84 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1 a ns1:TrainStation ;
#     ns1:City 1000 ;
#     ns1:department "Ain"^^xsd:string ;
#     ns1:latitude "46.196"^^xsd:float ;
#     ns1:longitude "5.275"^^xsd:float ;
#     ns1:name "Bourg-en-Bresse"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 84 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:10 a ns1:TrainStation ;
#     ns1:City 8200 ;
#     ns1:department "Ardennes"^^xsd:string ;
#     ns1:latitude "49.705"^^xsd:float ;
#     ns1:longitude "4.943"^^xsd:float ;
#     ns1:name "Sedan"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 44 ;
#     ns1:wifi "Non"^^xsd:string .
#
# ns1:100 a ns1:TrainStation ;
#     ns1:City 64100 ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.503"^^xsd:float ;
#     ns1:longitude "-1.443"^^xsd:float ;
#     ns1:name "Bayonne"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 75 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1000 a ns1:Museum ;
#     ns1:City 33500.0 ;
#     ns1:Localisation "42 Place Abel Surchamp"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.914487"^^xsd:float ;
#     ns1:longitude "-0.24506799999999998"^^xsd:float ;
#     ns1:name "musée des beaux-arts et d'archéologie"^^xsd:string .
#
# ns1:1001 a ns1:Museum ;
#     ns1:City 33000.0 ;
#     ns1:Localisation "20, cours d'Albret"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.838056"^^xsd:float ;
#     ns1:longitude "-0.579413"^^xsd:float ;
#     ns1:name "musée des beaux-arts"^^xsd:string .
#
# ns1:1002 a ns1:Museum ;
#     ns1:City 33000.0 ;
#     ns1:Localisation "39 rue Bouffard"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.838956"^^xsd:float ;
#     ns1:longitude "-0.5796859999999999"^^xsd:float ;
#     ns1:name "musée des arts décoratifs et du design"^^xsd:string .
#
# ns1:1003 a ns1:Museum ;
#     ns1:City 33000.0 ;
#     ns1:Localisation "20 cours Pasteur"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.835543"^^xsd:float ;
#     ns1:longitude "-0.575205"^^xsd:float ;
#     ns1:name "musée Goupil"^^xsd:string .
#
# ns1:1004 a ns1:Museum ;
#     ns1:City 33730.0 ;
#     ns1:Localisation "Rue Jean Lapeyre"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.457512"^^xsd:float ;
#     ns1:longitude "-0.372793"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1005 a ns1:Museum ;
#     ns1:City 33000.0 ;
#     ns1:Localisation "48 rue Vital Carles"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.838651"^^xsd:float ;
#     ns1:longitude "-0.577869"^^xsd:float ;
#     ns1:name "centre national Jean Moulin"^^xsd:string .
#
# ns1:1006 a ns1:Museum ;
#     ns1:City 33500.0 ;
#     ns1:Localisation "s'adresser à la mairie"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.9148033033"^^xsd:float ;
#     ns1:longitude "-0.24517994950000002"^^xsd:float ;
#     ns1:name "musée historique du vieux Libourne"^^xsd:string .
#
# ns1:1007 a ns1:Museum ;
#     ns1:City 33330.0 ;
#     ns1:Localisation "s'adresser à la mairie"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.8946175928"^^xsd:float ;
#     ns1:longitude "-0.1557084306"^^xsd:float ;
#     ns1:name "musée d'histoire et d'archéologie"^^xsd:string .
#
# ns1:1008 a ns1:Museum ;
#     ns1:City 87290.0 ;
#     ns1:Localisation "1 place Saint-Thyrse"^^xsd:string ;
#     ns1:department "Haute-Vienne"^^xsd:string ;
#     ns1:latitude "46.13125"^^xsd:float ;
#     ns1:longitude "1.274322"^^xsd:float ;
#     ns1:name "musée René Baubérot"^^xsd:string .
#
# ns1:1009 a ns1:Museum ;
#     ns1:City 87600.0 ;
#     ns1:Localisation "None"^^xsd:string ;
#     ns1:department "Haute-Vienne"^^xsd:string ;
#     ns1:latitude "45.822521"^^xsd:float ;
#     ns1:longitude "0.820506"^^xsd:float ;
#     ns1:name "musée départemental d'art contemporain"^^xsd:string .
#
# ns1:101 a ns1:TrainStation ;
#     ns1:City 64200 ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.472"^^xsd:float ;
#     ns1:longitude "-1.5550000000000002"^^xsd:float ;
#     ns1:name "Biarritz"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 75 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1010 a ns1:Museum ;
#     ns1:City 87000.0 ;
#     ns1:Localisation "8 place Winston Churchill"^^xsd:string ;
#     ns1:department "Haute-Vienne"^^xsd:string ;
#     ns1:latitude "45.832531"^^xsd:float ;
#     ns1:longitude "1.252114"^^xsd:float ;
#     ns1:name "musée de la porcelaine Adrien Dubouché"^^xsd:string .
#
# ns1:1011 a ns1:Museum ;
#     ns1:City 87000.0 ;
#     ns1:Localisation "1 place de l'Evêché"^^xsd:string ;
#     ns1:department "Haute-Vienne"^^xsd:string ;
#     ns1:latitude "45.828784"^^xsd:float ;
#     ns1:longitude "1.265445"^^xsd:float ;
#     ns1:name "musée des beaux-arts de Limoges - Palais de l'évêché"^^xsd:string .
#
# ns1:1012 a ns1:Museum ;
#     ns1:City 40600.0 ;
#     ns1:Localisation "332, avenue Louis Breguet"^^xsd:string ;
#     ns1:department "Landes"^^xsd:string ;
#     ns1:latitude "44.388887"^^xsd:float ;
#     ns1:longitude "-1.182563"^^xsd:float ;
#     ns1:name "musée historique de l'hydravion"^^xsd:string .
#
# ns1:1013 a ns1:Museum ;
#     ns1:City 40430.0 ;
#     ns1:Localisation "None"^^xsd:string ;
#     ns1:department "Landes"^^xsd:string ;
#     ns1:latitude "44.262826"^^xsd:float ;
#     ns1:longitude "-0.520865"^^xsd:float ;
#     ns1:name "atelier-musée"^^xsd:string .
#
# ns1:1014 a ns1:Museum ;
#     ns1:City 40300.0 ;
#     ns1:Localisation "785 route de l'abbaye"^^xsd:string ;
#     ns1:department "Landes"^^xsd:string ;
#     ns1:latitude "43.52735"^^xsd:float ;
#     ns1:longitude "-1.12142"^^xsd:float ;
#     ns1:name "musée départemental d'Histoire et d'Archéologie"^^xsd:string .
#
# ns1:1015 a ns1:Museum ;
#     ns1:City 40460.0 ;
#     ns1:Localisation "Place de la Mairie"^^xsd:string ;
#     ns1:department "Landes"^^xsd:string ;
#     ns1:latitude "44.483822"^^xsd:float ;
#     ns1:longitude "-1.075791"^^xsd:float ;
#     ns1:name "musée archéologique"^^xsd:string .
#
# ns1:1016 a ns1:Museum ;
#     ns1:City 40100.0 ;
#     ns1:Localisation "11 Bis rue des Carmes"^^xsd:string ;
#     ns1:department "Landes"^^xsd:string ;
#     ns1:latitude "43.710655"^^xsd:float ;
#     ns1:longitude "-1.054061"^^xsd:float ;
#     ns1:name "musée de Borda"^^xsd:string .
#
# ns1:1017 a ns1:Museum ;
#     ns1:City 40380.0 ;
#     ns1:Localisation "480 chemin de Sala"^^xsd:string ;
#     ns1:department "Landes"^^xsd:string ;
#     ns1:latitude "43.715749"^^xsd:float ;
#     ns1:longitude "-0.833916"^^xsd:float ;
#     ns1:name "musée des arts et traditions populaires de la Chalosse"^^xsd:string .
#
# ns1:1018 a ns1:Museum ;
#     ns1:City 40000.0 ;
#     ns1:Localisation "place Marguerite de Navarre"^^xsd:string ;
#     ns1:department "Landes"^^xsd:string ;
#     ns1:latitude "43.8926"^^xsd:float ;
#     ns1:longitude "-0.498893"^^xsd:float ;
#     ns1:name "musée Despiau-Wlérick"^^xsd:string .
#
# ns1:1019 a ns1:Museum ;
#     ns1:City 40630.0 ;
#     ns1:Localisation "Route de Solférino"^^xsd:string ;
#     ns1:department "Landes"^^xsd:string ;
#     ns1:latitude "44.149414"^^xsd:float ;
#     ns1:longitude "-0.749433"^^xsd:float ;
#     ns1:name "écomusée de la Grande Lande"^^xsd:string .
#
# ns1:102 a ns1:TrainStation ;
#     ns1:City 64700 ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.355"^^xsd:float ;
#     ns1:longitude "-1.774"^^xsd:float ;
#     ns1:name "Hendaye"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 75 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1020 a ns1:Museum ;
#     ns1:City 40500.0 ;
#     ns1:Localisation "Rue Lamarques"^^xsd:string ;
#     ns1:department "Landes"^^xsd:string ;
#     ns1:latitude "43.758542"^^xsd:float ;
#     ns1:longitude "-0.572168"^^xsd:float ;
#     ns1:name "musée d'Art et d'Histoire du Cap de Gascogne"^^xsd:string .
#
# ns1:1021 a ns1:Museum ;
#     ns1:City 40320.0 ;
#     ns1:Localisation "2378 route d’Hagetmau"^^xsd:string ;
#     ns1:department "Landes"^^xsd:string ;
#     ns1:latitude "43.641006"^^xsd:float ;
#     ns1:longitude "-0.510832"^^xsd:float ;
#     ns1:name "musée départemental de la Faïence et des Arts de la table"^^xsd:string .
#
# ns1:1022 a ns1:Museum ;
#     ns1:City 47200.0 ;
#     ns1:Localisation "15 rue Abel Boyé"^^xsd:string ;
#     ns1:department "Lot-et-Garonne"^^xsd:string ;
#     ns1:latitude "44.498918"^^xsd:float ;
#     ns1:longitude "0.166067"^^xsd:float ;
#     ns1:name "musée municipal Albert Marzelles"^^xsd:string .
#
# ns1:1023 a ns1:Museum ;
#     ns1:City 47600.0 ;
#     ns1:Localisation "Rue Henri IV"^^xsd:string ;
#     ns1:department "Lot-et-Garonne"^^xsd:string ;
#     ns1:latitude "44.135038"^^xsd:float ;
#     ns1:longitude "0.339995"^^xsd:float ;
#     ns1:name "musée du château"^^xsd:string .
#
# ns1:1024 a ns1:Museum ;
#     ns1:City 47170.0 ;
#     ns1:Localisation "Rue du puits saint Côme"^^xsd:string ;
#     ns1:department "Lot-et-Garonne"^^xsd:string ;
#     ns1:latitude "44.056939"^^xsd:float ;
#     ns1:longitude "0.256362"^^xsd:float ;
#     ns1:name "musée du liège et du bouchon"^^xsd:string .
#
# ns1:1025 a ns1:Museum ;
#     ns1:City 47500.0 ;
#     ns1:Localisation "Le bourg"^^xsd:string ;
#     ns1:department "Lot-et-Garonne"^^xsd:string ;
#     ns1:latitude "44.597987"^^xsd:float ;
#     ns1:longitude "1.017451"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1026 a ns1:Museum ;
#     ns1:City 47000.0 ;
#     ns1:Localisation "place du Dr Esquirol"^^xsd:string ;
#     ns1:department "Lot-et-Garonne"^^xsd:string ;
#     ns1:latitude "44.202895"^^xsd:float ;
#     ns1:longitude "0.615471"^^xsd:float ;
#     ns1:name "musée municipal des beaux-arts"^^xsd:string .
#
# ns1:1027 a ns1:Museum ;
#     ns1:City 47300.0 ;
#     ns1:Localisation "2, rue des Jardins"^^xsd:string ;
#     ns1:department "Lot-et-Garonne"^^xsd:string ;
#     ns1:latitude "44.405095"^^xsd:float ;
#     ns1:longitude "0.707815"^^xsd:float ;
#     ns1:name "musée municipal de Gajac"^^xsd:string .
#
# ns1:1028 a ns1:Museum ;
#     ns1:City 64260.0 ;
#     ns1:Localisation "rue des Eglises"^^xsd:string ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.105742"^^xsd:float ;
#     ns1:longitude "-0.42753399999999997"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1029 a ns1:Museum ;
#     ns1:City 64000.0 ;
#     ns1:Localisation "rue Mathieu Lalanne"^^xsd:string ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.297254"^^xsd:float ;
#     ns1:longitude "-0.364384"^^xsd:float ;
#     ns1:name "musée des beaux-arts"^^xsd:string .
#
# ns1:103 a ns1:TrainStation ;
#     ns1:City 64300 ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.491"^^xsd:float ;
#     ns1:longitude "-0.768"^^xsd:float ;
#     ns1:name "Orthez"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 75 ;
#     ns1:wifi "Non"^^xsd:string .
#
# ns1:1030 a ns1:Museum ;
#     ns1:City 64000.0 ;
#     ns1:Localisation "8 rue Tran"^^xsd:string ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.297209"^^xsd:float ;
#     ns1:longitude "-0.37252599999999997"^^xsd:float ;
#     ns1:name "musée Bernadotte"^^xsd:string .
#
# ns1:1031 a ns1:Museum ;
#     ns1:City 64000.0 ;
#     ns1:Localisation "2 rue du Château"^^xsd:string ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.294699"^^xsd:float ;
#     ns1:longitude "-0.374378"^^xsd:float ;
#     ns1:name "musée national du château de Pau"^^xsd:string .
#
# ns1:1032 a ns1:Museum ;
#     ns1:City 64100.0 ;
#     ns1:Localisation "5 rue Jacques Laffitte"^^xsd:string ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.492108"^^xsd:float ;
#     ns1:longitude "-1.472299"^^xsd:float ;
#     ns1:name "musée Bonnat - Helleu, musée des beaux-arts de Bayonne"^^xsd:string .
#
# ns1:1033 a ns1:Museum ;
#     ns1:City 64250.0 ;
#     ns1:Localisation "route du Docteur Camino"^^xsd:string ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.366872"^^xsd:float ;
#     ns1:longitude "-1.41606"^^xsd:float ;
#     ns1:name "musée Edmond Rostand"^^xsd:string .
#
# ns1:1034 a ns1:Museum ;
#     ns1:City 64210.0 ;
#     ns1:Localisation "None"^^xsd:string ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.425653"^^xsd:float ;
#     ns1:longitude "-1.6091980000000001"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1035 a ns1:Museum ;
#     ns1:City 64400.0 ;
#     ns1:Localisation "Commune d'Oloron Sainte-Marie"^^xsd:string ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.18818"^^xsd:float ;
#     ns1:longitude "-0.604752"^^xsd:float ;
#     ns1:name "musée béarnais"^^xsd:string .
#
# ns1:1036 a ns1:Museum ;
#     ns1:City 64330.0 ;
#     ns1:Localisation "Route du Château"^^xsd:string ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.514297"^^xsd:float ;
#     ns1:longitude "-0.303415"^^xsd:float ;
#     ns1:name "musée gallo-romain"^^xsd:string .
#
# ns1:1037 a ns1:Museum ;
#     ns1:City 64109.0 ;
#     ns1:Localisation "1 avenue du Maréchal Leclerc"^^xsd:string ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.4936418765"^^xsd:float ;
#     ns1:longitude "-1.4751693307"^^xsd:float ;
#     ns1:name "muséum d'histoire naturelle"^^xsd:string .
#
# ns1:1038 a ns1:Museum ;
#     ns1:City 64100.0 ;
#     ns1:Localisation "37 quai des Corsaires"^^xsd:string ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.491093"^^xsd:float ;
#     ns1:longitude "-1.4738229999999999"^^xsd:float ;
#     ns1:name "musée basque"^^xsd:string .
#
# ns1:1039 a ns1:Museum ;
#     ns1:City 86100.0 ;
#     ns1:Localisation "3 rue Clément Krebs"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "46.81393"^^xsd:float ;
#     ns1:longitude "0.536238"^^xsd:float ;
#     ns1:name "musée municipal de l'hôtel de Sully"^^xsd:string .
#
# ns1:104 a ns1:TrainStation ;
#     ns1:City 64000 ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.295"^^xsd:float ;
#     ns1:longitude "-0.35000000000000003"^^xsd:float ;
#     ns1:name "Pau"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 75 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1040 a ns1:Museum ;
#     ns1:City 86500.0 ;
#     ns1:Localisation "9 Avenue Pasteur"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "46.428227"^^xsd:float ;
#     ns1:longitude "0.872962"^^xsd:float ;
#     ns1:name "musée d'art et d'histoire de Montmorillon"^^xsd:string .
#
# ns1:1041 a ns1:Museum ;
#     ns1:City 86000.0 ;
#     ns1:Localisation "101, rue du Père-de-la-Croix"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "46.575749"^^xsd:float ;
#     ns1:longitude "0.35950899999999997"^^xsd:float ;
#     ns1:name "musée de l'hypogée des Dunes"^^xsd:string .
#
# ns1:1042 a ns1:Museum ;
#     ns1:City 86200.0 ;
#     ns1:Localisation "24 rue du Martray"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "47.009976"^^xsd:float ;
#     ns1:longitude "0.07574299999999999"^^xsd:float ;
#     ns1:name "musée Charbonneau-Lassay"^^xsd:string .
#
# ns1:1043 a ns1:Museum ;
#     ns1:City 86000.0 ;
#     ns1:Localisation "Rue Jean-Jaurès"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "46.580519"^^xsd:float ;
#     ns1:longitude "0.34610399999999997"^^xsd:float ;
#     ns1:name "musée du baptistère Saint-Jean"^^xsd:string .
#
# ns1:1044 a ns1:Museum ;
#     ns1:City 86100.0 ;
#     ns1:Localisation "3 rue Clément Krebs"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "46.81393"^^xsd:float ;
#     ns1:longitude "0.536238"^^xsd:float ;
#     ns1:name "musée de la moto, de l'automobile et du vélo"^^xsd:string .
#
# ns1:1045 a ns1:Museum ;
#     ns1:City 86320.0 ;
#     ns1:Localisation "21 Route de Montmorillon"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "46.403482"^^xsd:float ;
#     ns1:longitude "0.7256659999999999"^^xsd:float ;
#     ns1:name "musée de la Préhistoire Raymond Touchard"^^xsd:string .
#
# ns1:1046 a ns1:Museum ;
#     ns1:City 86000.0 ;
#     ns1:Localisation "1, Place de la Cathédrale"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "46.580584"^^xsd:float ;
#     ns1:longitude "0.348113"^^xsd:float ;
#     ns1:name "collection d'histoire naturelle"^^xsd:string .
#
# ns1:1047 a ns1:Museum ;
#     ns1:City 86300.0 ;
#     ns1:Localisation "Place du Vieux Marché, cité médiévale"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "46.5710354316"^^xsd:float ;
#     ns1:longitude "0.6478487284000001"^^xsd:float ;
#     ns1:name "musée archéologique et d'ethnographie locale"^^xsd:string .
#
# ns1:1048 a ns1:Museum ;
#     ns1:City 86400.0 ;
#     ns1:Localisation "2 place Leclerc"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "46.147599"^^xsd:float ;
#     ns1:longitude "0.296434"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1049 a ns1:Museum ;
#     ns1:City 86000.0 ;
#     ns1:Localisation "9, rue Victor Hugo"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "46.580602"^^xsd:float ;
#     ns1:longitude "0.337972"^^xsd:float ;
#     ns1:name "musée Rupert de Chièvres"^^xsd:string .
#
# ns1:105 a ns1:TrainStation ;
#     ns1:City 64500 ;
#     ns1:department "Pyrénées-Atlantiques"^^xsd:string ;
#     ns1:latitude "43.381"^^xsd:float ;
#     ns1:longitude "-1.6760000000000002"^^xsd:float ;
#     ns1:name "Saint-Jean-de-Luz - Ciboure"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 75 ;
#     ns1:wifi "Non"^^xsd:string .
#
# ns1:1050 a ns1:Museum ;
#     ns1:City 86000.0 ;
#     ns1:Localisation "3 bis rue Jean Jaurès"^^xsd:string ;
#     ns1:department "Vienne"^^xsd:string ;
#     ns1:latitude "46.581142"^^xsd:float ;
#     ns1:longitude "0.34443399999999996"^^xsd:float ;
#     ns1:name "musée Sainte-Croix"^^xsd:string .
#
# ns1:1051 a ns1:Museum ;
#     ns1:City 9190.0 ;
#     ns1:Localisation "route de Montjoie"^^xsd:string ;
#     ns1:department "Ariège"^^xsd:string ;
#     ns1:latitude "43.001452"^^xsd:float ;
#     ns1:longitude "1.143469"^^xsd:float ;
#     ns1:name "musée du palais des évêques"^^xsd:string .
#
# ns1:1052 a ns1:Museum ;
#     ns1:City 9300.0 ;
#     ns1:Localisation "32, village"^^xsd:string ;
#     ns1:department "Ariège"^^xsd:string ;
#     ns1:latitude "42.871095"^^xsd:float ;
#     ns1:longitude "1.8328579999999999"^^xsd:float ;
#     ns1:name "musée d'archéologie"^^xsd:string .
#
# ns1:1053 a ns1:Museum ;
#     ns1:City 9330.0 ;
#     ns1:Localisation "route de Paris"^^xsd:string ;
#     ns1:department "Ariège"^^xsd:string ;
#     ns1:latitude "42.940925"^^xsd:float ;
#     ns1:longitude "1.630459"^^xsd:float ;
#     ns1:name "musée de la forge"^^xsd:string .
#
# ns1:1054 a ns1:Museum ;
#     ns1:City 9000.0 ;
#     ns1:Localisation "rue du Rocher"^^xsd:string ;
#     ns1:department "Ariège"^^xsd:string ;
#     ns1:latitude "42.965864"^^xsd:float ;
#     ns1:longitude "1.6053000000000002"^^xsd:float ;
#     ns1:name "musée départemental de l'Ariège"^^xsd:string .
#
# ns1:1055 a ns1:Museum ;
#     ns1:City 9300.0 ;
#     ns1:Localisation "65, rue Jean Canal"^^xsd:string ;
#     ns1:department "Ariège"^^xsd:string ;
#     ns1:latitude "42.929968"^^xsd:float ;
#     ns1:longitude "1.845351"^^xsd:float ;
#     ns1:name "musée du textile et du peigne en corne"^^xsd:string .
#
# ns1:1056 a ns1:Museum ;
#     ns1:City 9290.0 ;
#     ns1:Localisation "place de l'Eglise"^^xsd:string ;
#     ns1:department "Ariège"^^xsd:string ;
#     ns1:latitude "43.079849"^^xsd:float ;
#     ns1:longitude "1.360358"^^xsd:float ;
#     ns1:name "musée de la préhistoire"^^xsd:string .
#
# ns1:1057 a ns1:Museum ;
#     ns1:City 11300.0 ;
#     ns1:Localisation "32 Promenade du Tivoli"^^xsd:string ;
#     ns1:department "Aude"^^xsd:string ;
#     ns1:latitude "43.053489"^^xsd:float ;
#     ns1:longitude "2.2143"^^xsd:float ;
#     ns1:name "musée Petiet"^^xsd:string .
#
# ns1:1058 a ns1:Museum ;
#     ns1:City 11108.0 ;
#     ns1:Localisation "place de l'Hôtel de Ville"^^xsd:string ;
#     ns1:department "Aude"^^xsd:string ;
#     ns1:latitude "43.184165347"^^xsd:float ;
#     ns1:longitude "3.0042705337"^^xsd:float ;
#     ns1:name "Palais-musée des Archevêques de Narbonne"^^xsd:string .
#
# ns1:1059 a ns1:Museum ;
#     ns1:City 11100.0 ;
#     ns1:Localisation "2, avenue André Mècle"^^xsd:string ;
#     ns1:department "Aude"^^xsd:string ;
#     ns1:latitude "43.1759336366"^^xsd:float ;
#     ns1:longitude "3.0261852745"^^xsd:float ;
#     ns1:name "musée Narbo Via"^^xsd:string .
#
# ns1:106 a ns1:TrainStation ;
#     ns1:City 65100 ;
#     ns1:department "Hautes-Pyrénées"^^xsd:string ;
#     ns1:latitude "43.095"^^xsd:float ;
#     ns1:longitude "-0.049"^^xsd:float ;
#     ns1:name "Lourdes"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 76 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1060 a ns1:Museum ;
#     ns1:City 11400.0 ;
#     ns1:Localisation "Presidial"^^xsd:string ;
#     ns1:department "Aude"^^xsd:string ;
#     ns1:latitude "43.315299"^^xsd:float ;
#     ns1:longitude "1.9590480000000001"^^xsd:float ;
#     ns1:name "musée archéologique du Lauragais"^^xsd:string .
#
# ns1:1061 a ns1:Museum ;
#     ns1:City 11150.0 ;
#     ns1:Localisation "2 avenue du Razès"^^xsd:string ;
#     ns1:department "Aude"^^xsd:string ;
#     ns1:latitude "43.243772"^^xsd:float ;
#     ns1:longitude "2.116173"^^xsd:float ;
#     ns1:name "musée municicpal \"Eburomagus, musée archéologique\""^^xsd:string .
#
# ns1:1062 a ns1:Museum ;
#     ns1:City 11600.0 ;
#     ns1:Localisation "1 Route des Fournes"^^xsd:string ;
#     ns1:department "Aude"^^xsd:string ;
#     ns1:latitude "43.333993"^^xsd:float ;
#     ns1:longitude "2.379223"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1063 a ns1:Museum ;
#     ns1:City 11000.0 ;
#     ns1:Localisation "15 boulevard Camille Pelletan"^^xsd:string ;
#     ns1:department "Aude"^^xsd:string ;
#     ns1:latitude "43.211552"^^xsd:float ;
#     ns1:longitude "2.355531"^^xsd:float ;
#     ns1:name "musée des beaux-arts"^^xsd:string .
#
# ns1:1064 a ns1:Museum ;
#     ns1:City 11590.0 ;
#     ns1:Localisation "allée des Potiers"^^xsd:string ;
#     ns1:department "Aude"^^xsd:string ;
#     ns1:latitude "43.260661"^^xsd:float ;
#     ns1:longitude "2.9428739999999998"^^xsd:float ;
#     ns1:name "musée archéologique"^^xsd:string .
#
# ns1:1065 a ns1:Museum ;
#     ns1:City 11130.0 ;
#     ns1:Localisation "Place de la Libération"^^xsd:string ;
#     ns1:department "Aude"^^xsd:string ;
#     ns1:latitude "43.028689"^^xsd:float ;
#     ns1:longitude "2.979275"^^xsd:float ;
#     ns1:name "musée des Corbières"^^xsd:string .
#
# ns1:1066 a ns1:Museum ;
#     ns1:City 12500.0 ;
#     ns1:Localisation "Place Pierre Frontin"^^xsd:string ;
#     ns1:department "Aveyron"^^xsd:string ;
#     ns1:latitude "44.520841"^^xsd:float ;
#     ns1:longitude "2.760423"^^xsd:float ;
#     ns1:name "musée des mœurs et coutumes, musée du Rouergue"^^xsd:string .
#
# ns1:1067 a ns1:Museum ;
#     ns1:City 12000.0 ;
#     ns1:Localisation "14 place Raynaldy"^^xsd:string ;
#     ns1:department "Aveyron"^^xsd:string ;
#     ns1:latitude "44.349201"^^xsd:float ;
#     ns1:longitude "2.576408"^^xsd:float ;
#     ns1:name "musée Fenaille"^^xsd:string .
#
# ns1:1068 a ns1:Museum ;
#     ns1:City 12100.0 ;
#     ns1:Localisation "place Foch"^^xsd:string ;
#     ns1:department "Aveyron"^^xsd:string ;
#     ns1:latitude "44.097895"^^xsd:float ;
#     ns1:longitude "3.080595"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1069 a ns1:Museum ;
#     ns1:City 12120.0 ;
#     ns1:Localisation "Le placet"^^xsd:string ;
#     ns1:department "Aveyron"^^xsd:string ;
#     ns1:latitude "44.202302"^^xsd:float ;
#     ns1:longitude "2.587674"^^xsd:float ;
#     ns1:name "musée du charroi rural"^^xsd:string .
#
# ns1:107 a ns1:TrainStation ;
#     ns1:City 65000 ;
#     ns1:department "Hautes-Pyrénées"^^xsd:string ;
#     ns1:latitude "43.232"^^xsd:float ;
#     ns1:longitude "0.07100000000000001"^^xsd:float ;
#     ns1:name "Tarbes"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 76 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1070 a ns1:Museum ;
#     ns1:City 12500.0 ;
#     ns1:Localisation "38 rue Droite"^^xsd:string ;
#     ns1:department "Aveyron"^^xsd:string ;
#     ns1:latitude "44.521365"^^xsd:float ;
#     ns1:longitude "2.762702"^^xsd:float ;
#     ns1:name "musée Joseph Vaylet"^^xsd:string .
#
# ns1:1071 a ns1:Museum ;
#     ns1:City 12000.0 ;
#     ns1:Localisation "N°1, Place Clemenceau"^^xsd:string ;
#     ns1:department "Aveyron"^^xsd:string ;
#     ns1:latitude "44.349287"^^xsd:float ;
#     ns1:longitude "2.578079"^^xsd:float ;
#     ns1:name "musée des beaux-arts Denys Puech"^^xsd:string .
#
# ns1:1072 a ns1:Museum ;
#     ns1:City 12250.0 ;
#     ns1:Localisation "rue Saint-Pierre"^^xsd:string ;
#     ns1:department "Aveyron"^^xsd:string ;
#     ns1:latitude "43.975103"^^xsd:float ;
#     ns1:longitude "2.991651"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1073 a ns1:Museum ;
#     ns1:City 12330.0 ;
#     ns1:Localisation "Cour de la Filature"^^xsd:string ;
#     ns1:department "Aveyron"^^xsd:string ;
#     ns1:latitude "44.430577"^^xsd:float ;
#     ns1:longitude "2.483923"^^xsd:float ;
#     ns1:name "musée des arts et métiers"^^xsd:string .
#
# ns1:1074 a ns1:Museum ;
#     ns1:City 12200.0 ;
#     ns1:Localisation "place de la Fontaine"^^xsd:string ;
#     ns1:department "Aveyron"^^xsd:string ;
#     ns1:latitude "44.351353"^^xsd:float ;
#     ns1:longitude "2.036793"^^xsd:float ;
#     ns1:name "musée Urbain Cabrol"^^xsd:string .
#
# ns1:1075 a ns1:Museum ;
#     ns1:City 12005.0 ;
#     ns1:Localisation "Communauté d’Agglomération du Grand Rodez"^^xsd:string ;
#     ns1:department "Aveyron"^^xsd:string ;
#     ns1:latitude "44.3531304545"^^xsd:float ;
#     ns1:longitude "2.5679787879"^^xsd:float ;
#     ns1:name "musée Soulages"^^xsd:string .
#
# ns1:1076 a ns1:Museum ;
#     ns1:City 12300.0 ;
#     ns1:Localisation "Avenue Paul Ramadier"^^xsd:string ;
#     ns1:department "Aveyron"^^xsd:string ;
#     ns1:latitude "44.555515"^^xsd:float ;
#     ns1:longitude "2.266258"^^xsd:float ;
#     ns1:name "musée régional de géologie Pierre Vetter"^^xsd:string .
#
# ns1:1077 a ns1:Museum ;
#     ns1:City 30100.0 ;
#     ns1:Localisation "Rue de Brouzen"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "44.130014"^^xsd:float ;
#     ns1:longitude "4.070265"^^xsd:float ;
#     ns1:name "musée-bibliothèque Pierre-André Benoit"^^xsd:string .
#
# ns1:1078 a ns1:Museum ;
#     ns1:City 30300.0 ;
#     ns1:Localisation "Château de Beaucaire"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "43.808182"^^xsd:float ;
#     ns1:longitude "4.6427119999999995"^^xsd:float ;
#     ns1:name "musée municipal de la Vignasse"^^xsd:string .
#
# ns1:1079 a ns1:Museum ;
#     ns1:City 30000.0 ;
#     ns1:Localisation "place de la Maison Carrée"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "43.837904"^^xsd:float ;
#     ns1:longitude "4.35616"^^xsd:float ;
#     ns1:name "Carré d'art - musée d'art contemporain"^^xsd:string .
#
# ns1:108 a ns1:TrainStation ;
#     ns1:City 66027 ;
#     ns1:department "Pyrénées-Orientales"^^xsd:string ;
#     ns1:latitude "42.697"^^xsd:float ;
#     ns1:longitude "2.888"^^xsd:float ;
#     ns1:name "Perpignan"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 76 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1080 a ns1:Museum ;
#     ns1:City 30130.0 ;
#     ns1:Localisation "2 rue Saint-Jacques"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "44.255204"^^xsd:float ;
#     ns1:longitude "4.650869"^^xsd:float ;
#     ns1:name "musée départemental d'art sacré"^^xsd:string .
#
# ns1:1081 a ns1:Museum ;
#     ns1:City 30701.0 ;
#     ns1:Localisation "Place de l'Evêché"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "44.0126417249"^^xsd:float ;
#     ns1:longitude "4.4223024239"^^xsd:float ;
#     ns1:name "musée municipal Georges Borias"^^xsd:string .
#
# ns1:1082 a ns1:Museum ;
#     ns1:City 30400.0 ;
#     ns1:Localisation "3 rue de la République"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "43.965433"^^xsd:float ;
#     ns1:longitude "4.796403"^^xsd:float ;
#     ns1:name "musée Pierre de Luxembourg"^^xsd:string .
#
# ns1:1083 a ns1:Museum ;
#     ns1:City 30200.0 ;
#     ns1:Localisation "Place Auguste Mallet"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "44.161992"^^xsd:float ;
#     ns1:longitude "4.6198429999999995"^^xsd:float ;
#     ns1:name "musée Albert André"^^xsd:string .
#
# ns1:1084 a ns1:Museum ;
#     ns1:City 30100.0 ;
#     ns1:Localisation "rue Jean Mayodon"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "44.129352"^^xsd:float ;
#     ns1:longitude "4.080982"^^xsd:float ;
#     ns1:name "musée du Colombier"^^xsd:string .
#
# ns1:1085 a ns1:Museum ;
#     ns1:City 30200.0 ;
#     ns1:Localisation "24 avenue Paul Langevin"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "44.164822"^^xsd:float ;
#     ns1:longitude "4.621051"^^xsd:float ;
#     ns1:name "musée Léon Alègre"^^xsd:string .
#
# ns1:1086 a ns1:Museum ;
#     ns1:City 30120.0 ;
#     ns1:Localisation "1 rue des Calquières"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "43.988997"^^xsd:float ;
#     ns1:longitude "3.606934"^^xsd:float ;
#     ns1:name "musée cévenol"^^xsd:string .
#
# ns1:1087 a ns1:Museum ;
#     ns1:City 30000.0 ;
#     ns1:Localisation "16, Boulevard des Arènes"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "43.837616"^^xsd:float ;
#     ns1:longitude "4.362815"^^xsd:float ;
#     ns1:name "musée de la Romanité"^^xsd:string .
#
# ns1:1088 a ns1:Museum ;
#     ns1:City 30000.0 ;
#     ns1:Localisation "rue  Cité-Foulc"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "43.832001"^^xsd:float ;
#     ns1:longitude "4.36081"^^xsd:float ;
#     ns1:name "musée des beaux-arts"^^xsd:string .
#
# ns1:1089 a ns1:Museum ;
#     ns1:City 30270.0 ;
#     ns1:Localisation "35 grand rue"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "44.104188"^^xsd:float ;
#     ns1:longitude "3.887004"^^xsd:float ;
#     ns1:name "maison Rouge - musée des vallées cévenoles"^^xsd:string .
#
# ns1:109 a ns1:TrainStation ;
#     ns1:City 67700 ;
#     ns1:department "Bas-Rhin"^^xsd:string ;
#     ns1:latitude "48.744"^^xsd:float ;
#     ns1:longitude "7.359"^^xsd:float ;
#     ns1:name "Saverne"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 44 ;
#     ns1:wifi "Non"^^xsd:string .
#
# ns1:1090 a ns1:Museum ;
#     ns1:City 30033.0 ;
#     ns1:Localisation "13 Boulevard Courbet"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "43.8379809976"^^xsd:float ;
#     ns1:longitude "4.3637121393000005"^^xsd:float ;
#     ns1:name "muséum d'histoire naturelle et de préhistoire"^^xsd:string .
#
# ns1:1091 a ns1:Museum ;
#     ns1:City 30000.0 ;
#     ns1:Localisation "place aux Herbes"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "43.838204"^^xsd:float ;
#     ns1:longitude "4.359619"^^xsd:float ;
#     ns1:name "musée du vieux Nîmes"^^xsd:string .
#
# ns1:1092 a ns1:Museum ;
#     ns1:City 30800.0 ;
#     ns1:Localisation "Place de la Maison Romane"^^xsd:string ;
#     ns1:department "Gard"^^xsd:string ;
#     ns1:latitude "43.676985"^^xsd:float ;
#     ns1:longitude "4.431238"^^xsd:float ;
#     ns1:name "musée de la maison Romane"^^xsd:string .
#
# ns1:1093 a ns1:Museum ;
#     ns1:City 32100.0 ;
#     ns1:Localisation "2 rue Jules Ferry"^^xsd:string ;
#     ns1:department "Gers"^^xsd:string ;
#     ns1:latitude "43.960792"^^xsd:float ;
#     ns1:longitude "0.37285799999999997"^^xsd:float ;
#     ns1:name "musée de l'Armagnac"^^xsd:string .
#
# ns1:1094 a ns1:Museum ;
#     ns1:City 32230.0 ;
#     ns1:Localisation "Hôtel de Ville"^^xsd:string ;
#     ns1:department "Gers"^^xsd:string ;
#     ns1:latitude "43.524266"^^xsd:float ;
#     ns1:longitude "0.160982"^^xsd:float ;
#     ns1:name "musée Joseph Abeilhe"^^xsd:string .
#
# ns1:1095 a ns1:Museum ;
#     ns1:City 32800.0 ;
#     ns1:Localisation "Place de la République"^^xsd:string ;
#     ns1:department "Gers"^^xsd:string ;
#     ns1:latitude "43.862193"^^xsd:float ;
#     ns1:longitude "0.101384"^^xsd:float ;
#     ns1:name "musée archéologique"^^xsd:string .
#
# ns1:1096 a ns1:Museum ;
#     ns1:City 32700.0 ;
#     ns1:Localisation "Place du Général-de-Gaulle"^^xsd:string ;
#     ns1:department "Gers"^^xsd:string ;
#     ns1:latitude "43.933873"^^xsd:float ;
#     ns1:longitude "0.638007"^^xsd:float ;
#     ns1:name "musée d'archéologie"^^xsd:string .
#
# ns1:1097 a ns1:Museum ;
#     ns1:City 32300.0 ;
#     ns1:Localisation "13 rue de l'Evêché"^^xsd:string ;
#     ns1:department "Gers"^^xsd:string ;
#     ns1:latitude "43.515315"^^xsd:float ;
#     ns1:longitude "0.403452"^^xsd:float ;
#     ns1:name "musée des beaux-arts et des arts décoratifs"^^xsd:string .
#
# ns1:1098 a ns1:Museum ;
#     ns1:City 32000.0 ;
#     ns1:Localisation "4 place Louis Blanc"^^xsd:string ;
#     ns1:department "Gers"^^xsd:string ;
#     ns1:latitude "43.647171"^^xsd:float ;
#     ns1:longitude "0.587482"^^xsd:float ;
#     ns1:name "musée des Amériques - Auch"^^xsd:string .
#
# ns1:1099 a ns1:Museum ;
#     ns1:City 32600.0 ;
#     ns1:Localisation "Place de l'Hôtel de Ville"^^xsd:string ;
#     ns1:department "Gers"^^xsd:string ;
#     ns1:latitude "43.612852"^^xsd:float ;
#     ns1:longitude "1.08184"^^xsd:float ;
#     ns1:name "musée campanaire"^^xsd:string .
#
# ns1:11 a ns1:TrainStation ;
#     ns1:City 21000 ;
#     ns1:department "Aube"^^xsd:string ;
#     ns1:latitude "48.119"^^xsd:float ;
#     ns1:longitude "4.789"^^xsd:float ;
#     ns1:name "Dijon-Ville"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 44 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:110 a ns1:TrainStation ;
#     ns1:City 67600 ;
#     ns1:department "Bas-Rhin"^^xsd:string ;
#     ns1:latitude "48.265"^^xsd:float ;
#     ns1:longitude "7.441"^^xsd:float ;
#     ns1:name "Sélestat"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 44 ;
#     ns1:wifi "Non"^^xsd:string .
#
# ns1:1100 a ns1:Museum ;
#     ns1:City 31110.0 ;
#     ns1:Localisation "18 allée d'Etigny"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "42.789494"^^xsd:float ;
#     ns1:longitude "0.592035"^^xsd:float ;
#     ns1:name "musée du pays de Luchon"^^xsd:string .
#
# ns1:1101 a ns1:Museum ;
#     ns1:City 31510.0 ;
#     ns1:Localisation "Etudes & Conservation"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "43.022611"^^xsd:float ;
#     ns1:longitude "0.579433"^^xsd:float ;
#     ns1:name "musée archéologique"^^xsd:string .
#
# ns1:1102 a ns1:Museum ;
#     ns1:City 31000.0 ;
#     ns1:Localisation "1ter place Saint-Sernin"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "43.608897"^^xsd:float ;
#     ns1:longitude "1.441776"^^xsd:float ;
#     ns1:name "musée Saint-Raymond"^^xsd:string .
#
# ns1:1103 a ns1:Museum ;
#     ns1:City 31220.0 ;
#     ns1:Localisation "place du Donjon"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "43.199447"^^xsd:float ;
#     ns1:longitude "1.010287"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1104 a ns1:Museum ;
#     ns1:City 31806.0 ;
#     ns1:Localisation "35 boulevard Jean-Bepmale"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "43.1076044627"^^xsd:float ;
#     ns1:longitude "0.7257149135000001"^^xsd:float ;
#     ns1:name "Le Musée - Arts et Figures des Pyrénées Centrales"^^xsd:string .
#
# ns1:1105 a ns1:Museum ;
#     ns1:City 31400.0 ;
#     ns1:Localisation "43 rue des Martyrs-de-la-Libération"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "43.590964"^^xsd:float ;
#     ns1:longitude "1.4584000000000001"^^xsd:float ;
#     ns1:name "musée Georges Labit"^^xsd:string .
#
# ns1:1106 a ns1:Museum ;
#     ns1:City 31300.0 ;
#     ns1:Localisation "76 allée Charles de Fitte"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "43.600678"^^xsd:float ;
#     ns1:longitude "1.428998"^^xsd:float ;
#     ns1:name "Les Abattoirs, musée d'art moderne et contemporain"^^xsd:string .
#
# ns1:1107 a ns1:Museum ;
#     ns1:City 31420.0 ;
#     ns1:Localisation "Avenue de Bénabarre"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "43.216166"^^xsd:float ;
#     ns1:longitude "0.8800300000000001"^^xsd:float ;
#     ns1:name "musée-forum de l'Aurignacien"^^xsd:string .
#
# ns1:1108 a ns1:Museum ;
#     ns1:City 31000.0 ;
#     ns1:Localisation "7 rue du May"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "43.602258"^^xsd:float ;
#     ns1:longitude "1.4431319999999999"^^xsd:float ;
#     ns1:name "musée du vieux Toulouse"^^xsd:string .
#
# ns1:1109 a ns1:Museum ;
#     ns1:City 31000.0 ;
#     ns1:Localisation "21 rue de Metz"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "43.600562"^^xsd:float ;
#     ns1:longitude "1.445904"^^xsd:float ;
#     ns1:name "musée des Augustins"^^xsd:string .
#
# ns1:111 a ns1:TrainStation ;
#     ns1:City 67000 ;
#     ns1:department "Bas-Rhin"^^xsd:string ;
#     ns1:latitude "48.561"^^xsd:float ;
#     ns1:longitude "7.76"^^xsd:float ;
#     ns1:name "Strasbourg-Ville"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 44 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1110 a ns1:Museum ;
#     ns1:City 31000.0 ;
#     ns1:Localisation "13 rue de la Pleau"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "43.596898"^^xsd:float ;
#     ns1:longitude "1.4469349999999999"^^xsd:float ;
#     ns1:name "musée Paul Dupuy"^^xsd:string .
#
# ns1:1111 a ns1:Museum ;
#     ns1:City 31000.0 ;
#     ns1:Localisation "35 allées Jules Guesde"^^xsd:string ;
#     ns1:department "Haute-Garonne"^^xsd:string ;
#     ns1:latitude "43.594189"^^xsd:float ;
#     ns1:longitude "1.448945"^^xsd:float ;
#     ns1:name "muséum d'histoire naturelle"^^xsd:string .
#
# ns1:1112 a ns1:Museum ;
#     ns1:City 65200.0 ;
#     ns1:Localisation "boulevard de l'Hypérion"^^xsd:string ;
#     ns1:department "Hautes-Pyrénées"^^xsd:string ;
#     ns1:latitude "43.063744"^^xsd:float ;
#     ns1:longitude "0.146227"^^xsd:float ;
#     ns1:name "musée Salies"^^xsd:string .
#
# ns1:1113 a ns1:Museum ;
#     ns1:City 65130.0 ;
#     ns1:Localisation "None"^^xsd:string ;
#     ns1:department "Hautes-Pyrénées"^^xsd:string ;
#     ns1:latitude "43.114294"^^xsd:float ;
#     ns1:longitude "0.282555"^^xsd:float ;
#     ns1:name "musée-château Gaston Phébus"^^xsd:string .
#
# ns1:1114 a ns1:Museum ;
#     ns1:City 65200.0 ;
#     ns1:Localisation "Vallon de Salut-Rue Jean Rösch"^^xsd:string ;
#     ns1:department "Hautes-Pyrénées"^^xsd:string ;
#     ns1:latitude "43.051963"^^xsd:float ;
#     ns1:longitude "0.147001"^^xsd:float ;
#     ns1:name "muséum d'histoire naturelle"^^xsd:string .
#
# ns1:1115 a ns1:Museum ;
#     ns1:City 65100.0 ;
#     ns1:Localisation "25, rue du fort"^^xsd:string ;
#     ns1:department "Hautes-Pyrénées"^^xsd:string ;
#     ns1:latitude "43.096353"^^xsd:float ;
#     ns1:longitude "-0.048462"^^xsd:float ;
#     ns1:name "musée pyrénéen"^^xsd:string .
#
# ns1:1116 a ns1:Museum ;
#     ns1:City 65200.0 ;
#     ns1:Localisation "rue Hount-Blanque"^^xsd:string ;
#     ns1:department "Hautes-Pyrénées"^^xsd:string ;
#     ns1:latitude "43.065612"^^xsd:float ;
#     ns1:longitude "0.153699"^^xsd:float ;
#     ns1:name "musée de la vie quotidienne dans les Pyrénées"^^xsd:string .
#
# ns1:1117 a ns1:Museum ;
#     ns1:City 65120.0 ;
#     ns1:Localisation "None"^^xsd:string ;
#     ns1:department "Hautes-Pyrénées"^^xsd:string ;
#     ns1:latitude "42.870941"^^xsd:float ;
#     ns1:longitude "-0.002108"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1118 a ns1:Museum ;
#     ns1:City 65000.0 ;
#     ns1:Localisation "None"^^xsd:string ;
#     ns1:department "Hautes-Pyrénées"^^xsd:string ;
#     ns1:latitude "43.232141"^^xsd:float ;
#     ns1:longitude "0.073892"^^xsd:float ;
#     ns1:name "musée Massey"^^xsd:string .
#
# ns1:1119 a ns1:Museum ;
#     ns1:City 34500.0 ;
#     ns1:Localisation "7-9 rue Capus / Place de la révolution"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.341429"^^xsd:float ;
#     ns1:longitude "3.210533"^^xsd:float ;
#     ns1:name "musée des beaux-arts"^^xsd:string .
#
# ns1:112 a ns1:TrainStation ;
#     ns1:City 68000 ;
#     ns1:department "Haut-Rhin"^^xsd:string ;
#     ns1:latitude "48.077"^^xsd:float ;
#     ns1:longitude "7.361"^^xsd:float ;
#     ns1:name "Colmar"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 44 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1120 a ns1:Museum ;
#     ns1:City 34000.0 ;
#     ns1:Localisation "2 Place Pétrarque"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.610788"^^xsd:float ;
#     ns1:longitude "3.878349"^^xsd:float ;
#     ns1:name "musée du vieux Montpellier"^^xsd:string .
#
# ns1:1121 a ns1:Museum ;
#     ns1:City 34110.0 ;
#     ns1:Localisation "4, rue Lucien-Salette"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.447077"^^xsd:float ;
#     ns1:longitude "3.755055"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1122 a ns1:Museum ;
#     ns1:City 34210.0 ;
#     ns1:Localisation "Place du Monument-aux-morts"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.354299"^^xsd:float ;
#     ns1:longitude "2.746165"^^xsd:float ;
#     ns1:name "musée archéologique"^^xsd:string .
#
# ns1:1123 a ns1:Museum ;
#     ns1:City 34570.0 ;
#     ns1:Localisation "Rue de l'ancienne mairie"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.604855"^^xsd:float ;
#     ns1:longitude "3.736827"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:1124 a ns1:Museum ;
#     ns1:City 34500.0 ;
#     ns1:Localisation "Rampe du 96e"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.338908"^^xsd:float ;
#     ns1:longitude "3.215208"^^xsd:float ;
#     ns1:name "musée du biterrois"^^xsd:string .
#
# ns1:1125 a ns1:Museum ;
#     ns1:City 34140.0 ;
#     ns1:Localisation "Quai du Port de Pêche"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.446763"^^xsd:float ;
#     ns1:longitude "3.660714"^^xsd:float ;
#     ns1:name "musée de l'étang de Thau"^^xsd:string .
#
# ns1:1126 a ns1:Museum ;
#     ns1:City 34600.0 ;
#     ns1:Localisation "Espace Campanaire André Malraux - Avenue de la Gare"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.594707575"^^xsd:float ;
#     ns1:longitude "3.1132995755"^^xsd:float ;
#     ns1:name "musée de la cloche et de la sonnaille"^^xsd:string .
#
# ns1:1127 a ns1:Museum ;
#     ns1:City 34970.0 ;
#     ns1:Localisation "390 route de Pérols"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.566659"^^xsd:float ;
#     ns1:longitude "3.90858"^^xsd:float ;
#     ns1:name "musée archéologique"^^xsd:string .
#
# ns1:1128 a ns1:Museum ;
#     ns1:City 34220.0 ;
#     ns1:Localisation "6, rue du Barry"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.486827"^^xsd:float ;
#     ns1:longitude "2.761809"^^xsd:float ;
#     ns1:name "musée de préhistoire"^^xsd:string .
#
# ns1:1129 a ns1:Museum ;
#     ns1:City 34200.0 ;
#     ns1:Localisation "148 Rue François Desnoyer"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.395512"^^xsd:float ;
#     ns1:longitude "3.691204"^^xsd:float ;
#     ns1:name "musée Paul Valéry"^^xsd:string .
#
# ns1:113 a ns1:TrainStation ;
#     ns1:City 68053 ;
#     ns1:department "Haut-Rhin"^^xsd:string ;
#     ns1:latitude "47.746"^^xsd:float ;
#     ns1:longitude "7.34"^^xsd:float ;
#     ns1:name "Mulhouse-Ville"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 44 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1130 a ns1:Museum ;
#     ns1:City 34500.0 ;
#     ns1:Localisation "Rampe du 96e"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.338908"^^xsd:float ;
#     ns1:longitude "3.215208"^^xsd:float ;
#     ns1:name "muséum d'histoire naturelle"^^xsd:string .
#
# ns1:1131 a ns1:Museum ;
#     ns1:City 34300.0 ;
#     ns1:Localisation "Le Cap d'Agde"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.298047"^^xsd:float ;
#     ns1:longitude "3.476702"^^xsd:float ;
#     ns1:name "musée de l'Ephèbe"^^xsd:string .
#
# ns1:1132 a ns1:Museum ;
#     ns1:City 34300.0 ;
#     ns1:Localisation "5 rue de la Fraternité"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.311837"^^xsd:float ;
#     ns1:longitude "3.468587"^^xsd:float ;
#     ns1:name "musée agathois"^^xsd:string .
#
# ns1:1133 a ns1:Museum ;
#     ns1:City 34270.0 ;
#     ns1:Localisation "25 Rue des consuls"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.731232"^^xsd:float ;
#     ns1:longitude "3.809872"^^xsd:float ;
#     ns1:name "musée du Pic-Saint-Loup"^^xsd:string .
#
# ns1:1134 a ns1:Museum ;
#     ns1:City 34700.0 ;
#     ns1:Localisation "Square Georges Auric, rue de la République"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.731613"^^xsd:float ;
#     ns1:longitude "3.319595"^^xsd:float ;
#     ns1:name "musée de Lodève - hôtel du cardinal de Fleury"^^xsd:string .
#
# ns1:1135 a ns1:Museum ;
#     ns1:City 34400.0 ;
#     ns1:Localisation "Place des Martyrs de la Résistance"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.675458"^^xsd:float ;
#     ns1:longitude "4.133656"^^xsd:float ;
#     ns1:name "musée Louis Médard"^^xsd:string .
#
# ns1:1136 a ns1:Museum ;
#     ns1:City 34000.0 ;
#     ns1:Localisation "39 boulevard Bonne-Nouvelle"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.61135"^^xsd:float ;
#     ns1:longitude "3.8806849999999997"^^xsd:float ;
#     ns1:name "musée Fabre"^^xsd:string .
#
# ns1:1137 a ns1:Museum ;
#     ns1:City 34000.0 ;
#     ns1:Localisation "6 bis rue Montpelliéret"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.611112"^^xsd:float ;
#     ns1:longitude "3.8801829999999997"^^xsd:float ;
#     ns1:name "musée de l'hôtel d'Espeyran"^^xsd:string .
#
# ns1:1138 a ns1:Museum ;
#     ns1:City 34000.0 ;
#     ns1:Localisation "7, rue Jacques-Coeur"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.609524"^^xsd:float ;
#     ns1:longitude "3.879151"^^xsd:float ;
#     ns1:name "musée languedocien"^^xsd:string .
#
# ns1:1139 a ns1:Museum ;
#     ns1:City 34120.0 ;
#     ns1:Localisation "3, rue Albert-Paul Alliès"^^xsd:string ;
#     ns1:department "Hérault"^^xsd:string ;
#     ns1:latitude "43.461352"^^xsd:float ;
#     ns1:longitude "3.422892"^^xsd:float ;
#     ns1:name "musée Vulliod de Saint-Germain"^^xsd:string .
#
# ns1:114 a ns1:TrainStation ;
#     ns1:City 25870 ;
#     ns1:department "Rhône"^^xsd:string ;
#     ns1:latitude "45.985"^^xsd:float ;
#     ns1:longitude "4.7059999999999995"^^xsd:float ;
#     ns1:name "Besançon Franche-Comté TGV"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 84 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:1140 a ns1:Museum ;
#     ns1:City 46100.0 ;
#     ns1:Localisation "Espace Henri Vayssettes"^^xsd:string ;
#     ns1:department "Lot"^^xsd:string ;
#     ns1:latitude "44.613443"^^xsd:float ;
#     ns1:longitude "2.016469"^^xsd:float ;
#     ns1:name "musée d'histoire de Figeac"^^xsd:string .
#
# ns1:1141 a ns1:Museum ;
#     ns1:City 46100.0 ;
#     ns1:Localisation "Place Champollion"^^xsd:string ;
#     ns1:department "Lot"^^xsd:string ;
#     ns1:latitude "44.609472"^^xsd:float ;
#     ns1:longitude "2.034599"^^xsd:float ;
#     ns1:name "musée Champollion"^^xsd:string .
#
# ns1:1142 a ns1:Museum ;
#     ns1:City 46330.0 ;
#     ns1:Localisation "Domaine de Cuzals"^^xsd:string ;
#     ns1:department "Lot"^^xsd:string ;
#     ns1:latitude "44.533948"^^xsd:float ;
# ...
#     ns1:latitude "45.934295"^^xsd:float ;
#     ns1:longitude "-0.9627239999999999"^^xsd:float ;
#     ns1:name "musée de la maison de Pierre Loti"^^xsd:string .
#
# ns1:951 a ns1:Museum ;
#     ns1:City 17310.0 ;
#     ns1:Localisation "9 place Gambetta"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "45.942781"^^xsd:float ;
#     ns1:longitude "-1.307498"^^xsd:float ;
#     ns1:name "musée oléronais Aliénor d'Aquitaine"^^xsd:string .
#
# ns1:952 a ns1:Museum ;
#     ns1:City 17100.0 ;
#     ns1:Localisation "rue Victor Hugo"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "45.746235"^^xsd:float ;
#     ns1:longitude "-0.6320549999999999"^^xsd:float ;
#     ns1:name "musée du Présidial"^^xsd:string .
#
# ns1:953 a ns1:Museum ;
#     ns1:City 17137.0 ;
#     ns1:Localisation "Parvis de l'église"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "46.250245"^^xsd:float ;
#     ns1:longitude "-1.111861"^^xsd:float ;
#     ns1:name "musée de la mytiliculture"^^xsd:string .
#
# ns1:954 a ns1:Museum ;
#     ns1:City 17400.0 ;
#     ns1:Localisation "9 rue Regnaud"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "45.942607"^^xsd:float ;
#     ns1:longitude "-0.523425"^^xsd:float ;
#     ns1:name "musée municipal des cordeliers"^^xsd:string .
#
# ns1:955 a ns1:Museum ;
#     ns1:City 17410.0 ;
#     ns1:Localisation "13 avenue Victor Bouthillier"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "46.2055"^^xsd:float ;
#     ns1:longitude "-1.365288"^^xsd:float ;
#     ns1:name "musée Ernest Cognacq"^^xsd:string .
#
# ns1:956 a ns1:Museum ;
#     ns1:City 17123.0 ;
#     ns1:Localisation "ile d'AIX"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "46.011577"^^xsd:float ;
#     ns1:longitude "-1.176477"^^xsd:float ;
#     ns1:name "musée napoléonien et musée africain (annexes du musée national des châteaux de Malmaison et de Bois Préau)"^^xsd:string .
#
# ns1:957 a ns1:Museum ;
#     ns1:City 17000.0 ;
#     ns1:Localisation "28, rue Gargouleau"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "46.161969"^^xsd:float ;
#     ns1:longitude "-1.151552"^^xsd:float ;
#     ns1:name "musée des beaux-arts"^^xsd:string .
#
# ns1:958 a ns1:Museum ;
#     ns1:City 17000.0 ;
#     ns1:Localisation "2, rue Saint-Michel"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "46.159482"^^xsd:float ;
#     ns1:longitude "-1.150024"^^xsd:float ;
#     ns1:name "musée protestant"^^xsd:string .
#
# ns1:959 a ns1:Museum ;
#     ns1:City 17300.0 ;
#     ns1:Localisation "63 avenue de Gaulle"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "45.935666"^^xsd:float ;
#     ns1:longitude "-0.9625229999999999"^^xsd:float ;
#     ns1:name "musée d'art et d'histoire"^^xsd:string .
#
# ns1:96 a ns1:TrainStation ;
#     ns1:City 62185 ;
#     ns1:department "Pas-de-Calais"^^xsd:string ;
#     ns1:latitude "50.935"^^xsd:float ;
#     ns1:longitude "1.85"^^xsd:float ;
#     ns1:name "Calais - Fréthun"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 32 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:960 a ns1:Museum ;
#     ns1:City 17230.0 ;
#     ns1:Localisation "62, rue d'Aligre"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "46.309723"^^xsd:float ;
#     ns1:longitude "-0.991941"^^xsd:float ;
#     ns1:name "musée Capon"^^xsd:string .
#
# ns1:961 a ns1:Museum ;
#     ns1:City 17100.0 ;
#     ns1:Localisation "Esplanade André-Malraux"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "45.741605"^^xsd:float ;
#     ns1:longitude "-0.627956"^^xsd:float ;
#     ns1:name "musée archéologique"^^xsd:string .
#
# ns1:962 a ns1:Museum ;
#     ns1:City 17100.0 ;
#     ns1:Localisation "Rue Alsace-Lorraine"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "45.745991"^^xsd:float ;
#     ns1:longitude "-0.633096"^^xsd:float ;
#     ns1:name "musée de l'Echevinage"^^xsd:string .
#
# ns1:963 a ns1:Museum ;
#     ns1:City 17100.0 ;
#     ns1:Localisation "4 rue Monconseil"^^xsd:string ;
#     ns1:department "Charente-Maritime"^^xsd:string ;
#     ns1:latitude "45.743294"^^xsd:float ;
#     ns1:longitude "-0.634076"^^xsd:float ;
#     ns1:name "musée Dupuy-Mestreau"^^xsd:string .
#
# ns1:964 a ns1:Museum ;
#     ns1:City 19208.0 ;
#     ns1:Localisation "12 rue Michelet"^^xsd:string ;
#     ns1:department "Corrèze"^^xsd:string ;
#     ns1:latitude "45.547059966"^^xsd:float ;
#     ns1:longitude "2.3084355486"^^xsd:float ;
#     ns1:name "musée du pays d'Ussel"^^xsd:string .
#
# ns1:965 a ns1:Museum ;
#     ns1:City 19100.0 ;
#     ns1:Localisation "26 bis boulevard Jules Ferry"^^xsd:string ;
#     ns1:department "Corrèze"^^xsd:string ;
#     ns1:latitude "45.158512"^^xsd:float ;
#     ns1:longitude "1.535911"^^xsd:float ;
#     ns1:name "musée Labenche"^^xsd:string .
#
# ns1:966 a ns1:Museum ;
#     ns1:City 19800.0 ;
#     ns1:Localisation "4 Route du Musée"^^xsd:string ;
#     ns1:department "Corrèze"^^xsd:string ;
#     ns1:latitude "45.407742"^^xsd:float ;
#     ns1:longitude "1.9400789999999999"^^xsd:float ;
#     ns1:name "musée du président Jacques Chirac"^^xsd:string .
#
# ns1:967 a ns1:Museum ;
#     ns1:City 19000.0 ;
#     ns1:Localisation "Place Monseigneur Berteaud"^^xsd:string ;
#     ns1:department "Corrèze"^^xsd:string ;
#     ns1:latitude "45.267654"^^xsd:float ;
#     ns1:longitude "1.770791"^^xsd:float ;
#     ns1:name "musée du cloître"^^xsd:string .
#
# ns1:968 a ns1:Museum ;
#     ns1:City 19000.0 ;
#     ns1:Localisation "1 bis rue du 9 juin 44"^^xsd:string ;
#     ns1:department "Corrèze"^^xsd:string ;
#     ns1:latitude "45.260441"^^xsd:float ;
#     ns1:longitude "1.751522"^^xsd:float ;
#     ns1:name "musée de la mémoire et des industries tullistes"^^xsd:string .
#
# ns1:969 a ns1:Museum ;
#     ns1:City 23200.0 ;
#     ns1:Localisation "avenue des Lissiers"^^xsd:string ;
#     ns1:department "Creuse"^^xsd:string ;
#     ns1:latitude "45.954471"^^xsd:float ;
#     ns1:longitude "2.169905"^^xsd:float ;
#     ns1:name "musée départemental de la tapisserie"^^xsd:string .
#
# ns1:97 a ns1:TrainStation ;
#     ns1:City 62100 ;
#     ns1:department "Pas-de-Calais"^^xsd:string ;
#     ns1:latitude "50.43"^^xsd:float ;
#     ns1:longitude "3.063"^^xsd:float ;
#     ns1:name "Calais-Ville"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 32 ;
#     ns1:wifi "Non"^^xsd:string .
#
# ns1:970 a ns1:Museum ;
#     ns1:City 23000.0 ;
#     ns1:Localisation "22, avenue de la Sénatorerie"^^xsd:string ;
#     ns1:department "Creuse"^^xsd:string ;
#     ns1:latitude "46.165838"^^xsd:float ;
#     ns1:longitude "1.870758"^^xsd:float ;
#     ns1:name "musée d'art et d'archéologie"^^xsd:string .
#
# ns1:971 a ns1:Museum ;
#     ns1:City 79200.0 ;
#     ns1:Localisation "1 rue Vau Saint-Jacques"^^xsd:string ;
#     ns1:department "Deux-Sèvres"^^xsd:string ;
#     ns1:latitude "46.652064"^^xsd:float ;
#     ns1:longitude "-0.24942000000000003"^^xsd:float ;
#     ns1:name "musée d'art et d'histoire Georges Turpin"^^xsd:string .
#
# ns1:972 a ns1:Museum ;
#     ns1:City 79000.0 ;
#     ns1:Localisation "26 avenue de Limoges"^^xsd:string ;
#     ns1:department "Deux-Sèvres"^^xsd:string ;
#     ns1:latitude "46.321168"^^xsd:float ;
#     ns1:longitude "-0.454351"^^xsd:float ;
#     ns1:name "musée d'histoire naturelle"^^xsd:string .
#
# ns1:973 a ns1:Museum ;
#     ns1:City 79800.0 ;
#     ns1:Localisation "La Chapelle"^^xsd:string ;
#     ns1:department "Deux-Sèvres"^^xsd:string ;
#     ns1:latitude "46.374565"^^xsd:float ;
#     ns1:longitude "-0.06743299999999999"^^xsd:float ;
#     ns1:name "musée des Tumulus"^^xsd:string .
#
# ns1:974 a ns1:Museum ;
#     ns1:City 79300.0 ;
#     ns1:Localisation "Place de l'Hôtel de Ville"^^xsd:string ;
#     ns1:department "Deux-Sèvres"^^xsd:string ;
#     ns1:latitude "46.841873"^^xsd:float ;
#     ns1:longitude "-0.493243"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:975 a ns1:Museum ;
#     ns1:City 79000.0 ;
#     ns1:Localisation "28, avenue de Limoges"^^xsd:string ;
#     ns1:department "Deux-Sèvres"^^xsd:string ;
#     ns1:latitude "46.321065"^^xsd:float ;
#     ns1:longitude "-0.454107"^^xsd:float ;
#     ns1:name "musée Bernard d'Agesci"^^xsd:string .
#
# ns1:976 a ns1:Museum ;
#     ns1:City 79000.0 ;
#     ns1:Localisation "Rue Du Guesclin"^^xsd:string ;
#     ns1:department "Deux-Sèvres"^^xsd:string ;
#     ns1:latitude "46.329091"^^xsd:float ;
#     ns1:longitude "-0.509253"^^xsd:float ;
#     ns1:name "musée ethnographique et archéologique du Donjon"^^xsd:string .
#
# ns1:977 a ns1:Museum ;
#     ns1:City 79100.0 ;
#     ns1:Localisation "7 rue Marie de la Tour"^^xsd:string ;
#     ns1:department "Deux-Sèvres"^^xsd:string ;
#     ns1:latitude "46.973531"^^xsd:float ;
#     ns1:longitude "-0.217936"^^xsd:float ;
#     ns1:name "musée d'art et d'histoire Henri Barré"^^xsd:string .
#
# ns1:978 a ns1:Museum ;
#     ns1:City 24000.0 ;
#     ns1:Localisation "20 rue du 26e Régiment d'infanterie"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "45.179999"^^xsd:float ;
#     ns1:longitude "0.71269"^^xsd:float ;
#     ns1:name "musée gallo-romain de Vésunna"^^xsd:string .
#
# ns1:979 a ns1:Museum ;
#     ns1:City 24400.0 ;
#     ns1:Localisation "2-6 rue Raoul-Grassin"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "45.037634"^^xsd:float ;
#     ns1:longitude "0.36167299999999997"^^xsd:float ;
#     ns1:name "musée des arts et traditions populaires"^^xsd:string .
#
# ns1:98 a ns1:TrainStation ;
#     ns1:City 62630 ;
#     ns1:department "Pas-de-Calais"^^xsd:string ;
#     ns1:latitude "50.525"^^xsd:float ;
#     ns1:longitude "1.589"^^xsd:float ;
#     ns1:name "Étaples - Le Touquet"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 32 ;
#     ns1:wifi "Non"^^xsd:string .
#
# ns1:980 a ns1:Museum ;
#     ns1:City 24620.0 ;
#     ns1:Localisation "1 rue du musée"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "44.93608"^^xsd:float ;
#     ns1:longitude "1.01363"^^xsd:float ;
#     ns1:name "musée national de préhistoire"^^xsd:string .
#
# ns1:981 a ns1:Museum ;
#     ns1:City 24310.0 ;
#     ns1:Localisation "None"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "45.321359"^^xsd:float ;
#     ns1:longitude "0.5860139999999999"^^xsd:float ;
#     ns1:name "château de Bourdeilles"^^xsd:string .
#
# ns1:982 a ns1:Museum ;
#     ns1:City 24250.0 ;
#     ns1:Localisation "Place de la Halle"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "44.803211"^^xsd:float ;
#     ns1:longitude "1.214147"^^xsd:float ;
#     ns1:name "musée Paul Reclus"^^xsd:string .
#
# ns1:983 a ns1:Museum ;
#     ns1:City 24290.0 ;
#     ns1:Localisation "Place Bertran-de-Born"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "45.063722"^^xsd:float ;
#     ns1:longitude "1.163336"^^xsd:float ;
#     ns1:name "musée Eugène Le Roy"^^xsd:string .
#
# ns1:984 a ns1:Museum ;
#     ns1:City 24000.0 ;
#     ns1:Localisation "32, rue des Farges"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "45.183285"^^xsd:float ;
#     ns1:longitude "0.720943"^^xsd:float ;
#     ns1:name "musée militaire - souvenirs du Périgord"^^xsd:string .
#
# ns1:985 a ns1:Museum ;
#     ns1:City 24000.0 ;
#     ns1:Localisation "22, cours Tourny"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "45.186039"^^xsd:float ;
#     ns1:longitude "0.7239500000000001"^^xsd:float ;
#     ns1:name "musée d'art et d'archéologie du Périgord"^^xsd:string .
#
# ns1:986 a ns1:Museum ;
#     ns1:City 24440.0 ;
#     ns1:Localisation "None"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "44.77393"^^xsd:float ;
#     ns1:longitude "0.815624"^^xsd:float ;
#     ns1:name "musée de site médiéval"^^xsd:string .
#
# ns1:987 a ns1:Museum ;
#     ns1:City 24100.0 ;
#     ns1:Localisation "Place du Feu"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "44.84976"^^xsd:float ;
#     ns1:longitude "0.483469"^^xsd:float ;
#     ns1:name "musée du tabac"^^xsd:string .
#
# ns1:988 a ns1:Museum ;
#     ns1:City 24310.0 ;
#     ns1:Localisation "Boulevard Charlemagne"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "45.364385"^^xsd:float ;
#     ns1:longitude "0.647127"^^xsd:float ;
#     ns1:name "musée Fernand Desmoulin"^^xsd:string .
#
# ns1:989 a ns1:Museum ;
#     ns1:City 24300.0 ;
#     ns1:Localisation "Avenue du Général Leclerc"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "45.527264"^^xsd:float ;
#     ns1:longitude "0.660717"^^xsd:float ;
#     ns1:name "musée départemental de la poupée et du jouet"^^xsd:string .
#
# ns1:99 a ns1:TrainStation ;
#     ns1:City 62300 ;
#     ns1:department "Pas-de-Calais"^^xsd:string ;
#     ns1:latitude "50.419"^^xsd:float ;
#     ns1:longitude "3.027"^^xsd:float ;
#     ns1:name "Lens"^^xsd:string ;
#     ns1:numberOfUsers "high"^^xsd:string ;
#     ns1:region 32 ;
#     ns1:wifi "Oui"^^xsd:string .
#
# ns1:990 a ns1:Museum ;
#     ns1:City 24206.0 ;
#     ns1:Localisation "Mairie de Sarlat"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "44.8945637627"^^xsd:float ;
#     ns1:longitude "1.2330483276"^^xsd:float ;
#     ns1:name "musée de Sarlat et du Périgord noir"^^xsd:string .
#
# ns1:991 a ns1:Museum ;
#     ns1:City 24610.0 ;
#     ns1:Localisation "None"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "44.94827"^^xsd:float ;
#     ns1:longitude "0.056581"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:992 a ns1:Museum ;
#     ns1:City 24100.0 ;
#     ns1:Localisation "28, Site Bella Riva"^^xsd:string ;
#     ns1:department "Dordogne"^^xsd:string ;
#     ns1:latitude "44.854512"^^xsd:float ;
#     ns1:longitude "0.564759"^^xsd:float ;
#     ns1:name "musée-aquarium"^^xsd:string .
#
# ns1:993 a ns1:Museum ;
#     ns1:City 33390.0 ;
#     ns1:Localisation "Citadelle de Blaye"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "45.126358"^^xsd:float ;
#     ns1:longitude "-0.66364"^^xsd:float ;
#     ns1:name "musée d'art et d'histoire du pays blayais"^^xsd:string .
#
# ns1:994 a ns1:Museum ;
#     ns1:City 33000.0 ;
#     ns1:Localisation "20, cours Pasteur"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.835543"^^xsd:float ;
#     ns1:longitude "-0.575205"^^xsd:float ;
#     ns1:name "musée d'Aquitaine"^^xsd:string .
#
# ns1:995 a ns1:Museum ;
#     ns1:City 33710.0 ;
#     ns1:Localisation "Place du District"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "45.039017"^^xsd:float ;
#     ns1:longitude "-0.55971"^^xsd:float ;
#     ns1:name "musée de la voiture à cheval. Au temps des calèches"^^xsd:string .
#
# ns1:996 a ns1:Museum ;
#     ns1:City 33000.0 ;
#     ns1:Localisation "5, place Bardineau"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.848154"^^xsd:float ;
#     ns1:longitude "-0.580085"^^xsd:float ;
#     ns1:name "muséum d'histoire naturelle"^^xsd:string .
#
# ns1:997 a ns1:Museum ;
#     ns1:City 33540.0 ;
#     ns1:Localisation "None"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.748299"^^xsd:float ;
#     ns1:longitude "-0.074554"^^xsd:float ;
#     ns1:name "musée archéologique"^^xsd:string .
#
# ns1:998 a ns1:Museum ;
#     ns1:City 33000.0 ;
#     ns1:Localisation "7 rue Ferrère"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.848186"^^xsd:float ;
#     ns1:longitude "-0.572137"^^xsd:float ;
#     ns1:name "CAPC - musée d'art contemporain"^^xsd:string .
#
# ns1:999 a ns1:Museum ;
#     ns1:City 33190.0 ;
#     ns1:Localisation "Esplanade Charles de Gaulle"^^xsd:string ;
#     ns1:department "Gironde"^^xsd:string ;
#     ns1:latitude "44.581128"^^xsd:float ;
#     ns1:longitude "-0.041074"^^xsd:float ;
#     ns1:name "musée municipal"^^xsd:string .
#
# ns1:TrainStation rdfs:subClassOf ns1:Place .
#
# ns1:Museum rdfs:subClassOf ns1:Place .
# <Graph identifier=N5a5b8dfb36c54d1a8e4dd555964d1740 (<class 'rdflib.graph.Graph'>)>
